# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

rng = np.random.RandomState(0)
X = rng.randn(1000, 2)
X = (X > 0) * 2 - 1 + 0.3 * rng.randn(*X.shape)
Y = np.logical_xor(X[:,0] > 0, X[:,1] > 0).astype(int)

c0 = X[np.nonzero(Y)[0]]
c1 = X[np.nonzero(Y == 0)[0]]

plt.plot(c0[:,0], c0[:,1], 'ro', label='class 0')
plt.plot(c1[:,0], c1[:,1], 'bo', label='class 1')

plt.title('XOR') 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

batch_size=8

training_data = DataLoader(TensorDataset(torch.Tensor(X[:750,:]), torch.tensor(Y[:750], dtype=torch.long)), shuffle=True, batch_size=batch_size)
validation_data = DataLoader(TensorDataset(torch.Tensor(X[750:,:]), torch.tensor(Y[750:], dtype=torch.long)), batch_size=batch_size)

# %%
import numpy as np

# XOR dataset with [-1,1] values
X = np.array([[-1, -1], [-1, 1], [1, -1], [1, 1]])
Y = np.array([[-1], [1], [1], [-1]])

# Define a manually designed 3-perceptron network
def xor_perceptron(x1, x2):
    # First hidden layer (2 perceptrons)
    h1 = max(0, x1 + x2)  # ReLU activation
    h2 = max(0, -x1 - x2) # ReLU activation

    # Output perceptron (linear combination)
    output = 1 if (h1 - h2) > 0 else -1

    return output

# Test the manually defined network
results = [xor_perceptron(x1, x2) for x1, x2 in X]
print("Predictions:", results)
# Out:
# Using cpu device
# NeuralNetwork(
#   (activation): ReLU()
#   (first_hidden): Linear(in_features=2, out_features=10, bias=True)
#   (second_hidden): Linear(in_features=10, out_features=5, bias=True)
#   (output): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=5e-2)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data, model, loss_fn, optimizer)
    test(validation_data, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.693603  [    0/  750]
# Test Error:
#  Accuracy: 72.8%, Avg loss: 0.461942
#
# Epoch 2
# -------------------------------
# loss: 0.421529  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.224911
#
# Epoch 3
# -------------------------------
# loss: 0.160475  [    0/  750]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.127480
#
# Epoch 4
# -------------------------------
# loss: 0.059843  [    0/  750]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.085937
#
# Epoch 5
# -------------------------------
# loss: 0.101423  [    0/  750]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.063185
#
# Epoch 6
# -------------------------------
# loss: 0.063980  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.050101
#
# Epoch 7
# -------------------------------
# loss: 0.035934  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.041067
#
# Epoch 8
# -------------------------------
# loss: 0.018351  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.035042
#
# Epoch 9
# -------------------------------
# loss: 0.025289  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.030945
#
# Epoch 10
# -------------------------------
# loss: 0.011875  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.027170
#
# Epoch 11
# -------------------------------
# loss: 0.028956  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.024858
#
# Epoch 12
# -------------------------------
# loss: 0.010731  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.022621
#
# Epoch 13
# -------------------------------
# loss: 0.013839  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.020857
#
# Epoch 14
# -------------------------------
# loss: 0.009255  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.019359
#
# Epoch 15
# -------------------------------
# loss: 0.022254  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.018055
#
# Epoch 16
# -------------------------------
# loss: 0.002788  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.016984
#
# Epoch 17
# -------------------------------
# loss: 0.016105  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.016034
#
# Epoch 18
# -------------------------------
# loss: 0.001024  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.015210
#
# Epoch 19
# -------------------------------
# loss: 0.004391  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.014528
#
# Epoch 20
# -------------------------------
# loss: 0.009774  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.013874
#
# Epoch 21
# -------------------------------
# loss: 0.008460  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.013258
#
# Epoch 22
# -------------------------------
# loss: 0.011007  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.012758
#
# Epoch 23
# -------------------------------
# loss: 0.000414  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.012407
#
# Epoch 24
# -------------------------------
# loss: 0.006688  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.011905
#
# Epoch 25
# -------------------------------
# loss: 0.003021  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.011524
#
# Epoch 26
# -------------------------------
# loss: 0.004005  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.011155
#
# Epoch 27
# -------------------------------
# loss: 0.002931  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.010896
#
# Epoch 28
# -------------------------------
# loss: 0.003000  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.010565
#
# Epoch 29
# -------------------------------
# loss: 0.006199  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.010279
#
# Epoch 30
# -------------------------------
# loss: 0.005025  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.009997
#
# Epoch 31
# -------------------------------
# loss: 0.006996  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.009747
#
# Epoch 32
# -------------------------------
# loss: 0.004904  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.009526
#
# Epoch 33
# -------------------------------
# loss: 0.009532  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.009292
#
# Epoch 34
# -------------------------------
# loss: 0.005525  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.009116
#
# Epoch 35
# -------------------------------
# loss: 0.002009  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008968
#
# Epoch 36
# -------------------------------
# loss: 0.002454  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008793
#
# Epoch 37
# -------------------------------
# loss: 0.002274  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008639
#
# Epoch 38
# -------------------------------
# loss: 0.005837  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008483
#
# Epoch 39
# -------------------------------
# loss: 0.008829  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008287
#
# Epoch 40
# -------------------------------
# loss: 0.000926  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008169
#
# Epoch 41
# -------------------------------
# loss: 0.003440  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.008047
#
# Epoch 42
# -------------------------------
# loss: 0.005665  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007844
#
# Epoch 43
# -------------------------------
# loss: 0.003257  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007743
#
# Epoch 44
# -------------------------------
# loss: 0.003392  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007680
#
# Epoch 45
# -------------------------------
# loss: 0.004579  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007554
#
# Epoch 46
# -------------------------------
# loss: 0.000076  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007469
#
# Epoch 47
# -------------------------------
# loss: 0.004028  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007376
#
# Epoch 48
# -------------------------------
# loss: 0.007118  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007246
#
# Epoch 49
# -------------------------------
# loss: 0.003194  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007174
#
# Epoch 50
# -------------------------------
# loss: 0.002894  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007109
#
# Epoch 51
# -------------------------------
# loss: 0.003405  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.007026
#
# Epoch 52
# -------------------------------
# loss: 0.002725  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006923
#
# Epoch 53
# -------------------------------
# loss: 0.002552  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006835
#
# Epoch 54
# -------------------------------
# loss: 0.000079  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006780
#
# Epoch 55
# -------------------------------
# loss: 0.000515  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006712
#
# Epoch 56
# -------------------------------
# loss: 0.005336  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006650
#
# Epoch 57
# -------------------------------
# loss: 0.001216  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006579
#
# Epoch 58
# -------------------------------
# loss: 0.003423  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006568
#
# Epoch 59
# -------------------------------
# loss: 0.005526  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006503
#
# Epoch 60
# -------------------------------
# loss: 0.003460  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006423
#
# Epoch 61
# -------------------------------
# loss: 0.002235  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006369
#
# Epoch 62
# -------------------------------
# loss: 0.002419  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006325
#
# Epoch 63
# -------------------------------
# loss: 0.001134  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006234
#
# Epoch 64
# -------------------------------
# loss: 0.001039  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006179
#
# Epoch 65
# -------------------------------
# loss: 0.004072  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006118
#
# Epoch 66
# -------------------------------
# loss: 0.000997  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006071
#
# Epoch 67
# -------------------------------
# loss: 0.009429  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.006012
#
# Epoch 68
# -------------------------------
# loss: 0.002018  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005956
#
# Epoch 69
# -------------------------------
# loss: 0.001888  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005954
#
# Epoch 70
# -------------------------------
# loss: 0.004623  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005916
#
# Epoch 71
# -------------------------------
# loss: 0.000973  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005920
#
# Epoch 72
# -------------------------------
# loss: 0.002708  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005861
#
# Epoch 73
# -------------------------------
# loss: 0.000885  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005824
#
# Epoch 74
# -------------------------------
# loss: 0.001818  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005775
#
# Epoch 75
# -------------------------------
# loss: 0.000001  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005736
#
# Epoch 76
# -------------------------------
# loss: 0.001697  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005695
#
# Epoch 77
# -------------------------------
# loss: 0.000005  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005655
#
# Epoch 78
# -------------------------------
# loss: 0.000850  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005625
#
# Epoch 79
# -------------------------------
# loss: 0.003246  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005594
#
# Epoch 80
# -------------------------------
# loss: 0.000887  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005562
#
# Epoch 81
# -------------------------------
# loss: 0.001803  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005560
#
# Epoch 82
# -------------------------------
# loss: 0.000813  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005520
#
# Epoch 83
# -------------------------------
# loss: 0.000390  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005509
#
# Epoch 84
# -------------------------------
# loss: 0.001535  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005463
#
# Epoch 85
# -------------------------------
# loss: 0.003644  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005436
#
# Epoch 86
# -------------------------------
# loss: 0.003809  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005426
#
# Epoch 87
# -------------------------------
# loss: 0.000867  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005375
#
# Epoch 88
# -------------------------------
# loss: 0.001480  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005378
#
# Epoch 89
# -------------------------------
# loss: 0.000755  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005375
#
# Epoch 90
# -------------------------------
# loss: 0.001409  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005370
#
# Epoch 91
# -------------------------------
# loss: 0.000717  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005331
#
# Epoch 92
# -------------------------------
# loss: 0.002782  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005282
#
# Epoch 93
# -------------------------------
# loss: 0.000709  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005283
#
# Epoch 94
# -------------------------------
# loss: 0.000017  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005248
#
# Epoch 95
# -------------------------------
# loss: 0.003003  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005224
#
# Epoch 96
# -------------------------------
# loss: 0.002056  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005185
#
# Epoch 97
# -------------------------------
# loss: 0.002745  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005151
#
# Epoch 98
# -------------------------------
# loss: 0.000711  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005105
#
# Epoch 99
# -------------------------------
# loss: 0.000643  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005103
#
# Epoch 100
# -------------------------------
# loss: 0.000654  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.005084
#
# Done!

# %%
def predict(x):
    #Convert into numpy element to tensor
    x = torch.from_numpy(x).type(torch.FloatTensor).to(device)
    #Predict and return ans
    ans = torch.argmax(model(x), dim=1)
    return ans.to('cpu').detach().numpy()

# %%
# Helper function to plot a decision boundary.
def plot_decision_boundary(pred_func,X,Y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx,yy=np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.title('XOR')
    plt.xlabel('x axis')
    plt.ylabel('y axis')
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    # Plot ground truth
    c0 = X[np.nonzero(Y)[0]]
    c1 = X[np.nonzero(Y == 0)[0]]
    plt.plot(c0[:,0], c0[:,1], 'ko', label='class 0')
    plt.plot(c1[:,0], c1[:,1], 'wo', label='class 1')
    plt.legend()

# %%
plot_decision_boundary(predict, X, Y)
